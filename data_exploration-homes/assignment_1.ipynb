# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Exercise 1
# a) Load house sales data from file kc_house_data.csv, print first records.
# b) Print the variable list. Select categorical and numerical variables.
# c) Compute basic statistics of numerical variables. Are all of them meaningful?

# %%
#a)
#Your code:
df = pd.read_csv('./kc_house_data.csv')
df.head(10)

#Hint: read_csv(), head()
# Out:
#            id             date      price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000   221900.0         3       1.00         1180
# 1  6414100192  20141209T000000   538000.0         3       2.25         2570
# 2  5631500400  20150225T000000   180000.0         2       1.00          770
# 3  2487200875  20141209T000000   604000.0         4       3.00         1960
# 4  1954400510  20150218T000000   510000.0         3       2.00         1680
# 5  7237550310  20140512T000000  1225000.0         4       4.50         5420
# 6  1321400060  20140627T000000   257500.0         3       2.25         1715
# 7  2008000270  20150115T000000   291850.0         3       1.50         1060
# 8  2414600126  20150415T000000   229500.0         3       1.00         1780
# 9  3793500160  20150312T000000   323000.0         3       2.50         1890
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# ...

# %%
#b) 
list(df.columns.values)
# works as well
# list(df)

house_numerical_df = df[["price", "bedrooms", "bathrooms", "sqft_living", "sqft_lot", "floors", "sqft_above", "sqft_basement", "yr_built", "yr_renovated", "lat", "long", "sqft_living15", "sqft_lot15"]]
house_categorical_df = df[["waterfront", "view", "condition", "grade", "zipcode"]]

# %% [markdown]
# > Notes: <br>
# > - Variables like view, grade or condition (and the rest of them from `house_categorical_df`) are definitely categorical because they represent an affilliation to a certain group. For example binary variable `waterfront` divides the houses between two categories: "overlooking waterfront" and "not overlooking waterfront". Moreover, there is no point in calculating mathematical values like mean or sum from these variables (because they represent categories). <br>
# > - Variables from `house_numerical_df` are purely numerical and sensitive to operations like addition, taking averages, etc.
# > - I did not assign `id` and `date` variables to either numerical or categorical variables. Id or date does not represent any category but also taking mathematical operations on them does not make sense either.

# %%
#c)
#Your code:
house_numerical_df.describe()
#Hint: Function describe()
# Out:
#               price      bedrooms     bathrooms   sqft_living      sqft_lot  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  2.161300e+04
# mean   5.400881e+05      3.370842      2.114757   2079.899736  1.510697e+04
# std    3.671272e+05      0.930062      0.770163    918.440897  4.142051e+04
# min    7.500000e+04      0.000000      0.000000    290.000000  5.200000e+02
# 25%    3.219500e+05      3.000000      1.750000   1427.000000  5.040000e+03
# 50%    4.500000e+05      3.000000      2.250000   1910.000000  7.618000e+03
# 75%    6.450000e+05      4.000000      2.500000   2550.000000  1.068800e+04
# max    7.700000e+06     33.000000      8.000000  13540.000000  1.651359e+06
#
#              floors    sqft_above  sqft_basement      yr_built  yr_renovated  \
# count  21613.000000  21613.000000   21613.000000  21613.000000  21613.000000
# mean       1.494309   1788.390691     291.509045   1971.005136     84.402258
# ...

# %% [markdown]
# > Notes:<br>
# > - not all statistics of numerical variables are useful, for example `count` for all variables is equal to number of rows in the dataframe which is not that meaningful<br>
# > - when a house was not renovated `0` appears in the dataframe which completely ruins statistics for `yr_renovated` variable

# %% [markdown]
# ## Exercise 2
# Using scatter plot:
# a) Show the relation of square footage and price.
# b) Check how price is influenced by apartment's grade. Find other variables correlated with price.
# c) Check how good apartments are distributed over the city. First, plot zipcode versus price. Then, use apartments coordinates (longitude and lattitude) in order to show where apartments of good grade are located.

# %%
#a)
#Your code:
plt.xlabel("living sqft")
plt.ylabel("price")
plt.ticklabel_format(style='plain', axis='y')

plt.scatter(df["sqft_living"], df["price"])
#Hint plt.scatter

# %% [markdown]
# > Notes:<br>
# > - square footage and price are correlated weakly. In general bigger living space means more money but it is not the only facotr that matters, e.g. properties like location, condition or grade sometimes matter even more than just footage.
# > - we can spot some outliers (somewhere above 9000 living sqft)

# %%
#b)
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('grade')
plt.ylabel('price')
plt.scatter(df["grade"], df["price"])

# %% [markdown]
# > Notes:
# > - increasing grade means bigger price
# > - outliers occurs (especially for grade `13`)

# %%
#b) 
plt.ticklabel_format(style='plain', axis='y')
plt.xlabel('bathrooms')
plt.ylabel('price')
plt.scatter(df['bathrooms'], df['price'])

# %% [markdown]
# > Notes:
# > - number of bathrooms are also correleated to price but weakly

# %%
#c)
#Your code:
plt.scatter(df["zipcode"], df['price'])

# %% [markdown]
# > Notes:
# > - it looks like division into districts and indicative house prices in them

# %%
#Your code:
plt.figure(figsize=(10,8))
plt.scatter(df['long'], df['lat'], c=df['grade'], cmap='winter')

# %% [markdown]
# > Notes:
# > - apartments with highest grade are located in the center (probably in city center)

# %% [markdown]
# ## Exercise 3
# a) Create boxplot of apartment's grade versus it's price. Compare with plot 2b).
# b) Create mosaic plot of any two categorical variables.

# %%
#a)
#Your code:
# grades = list(range(df['grade'].min(), df['grade'].max() + 1))
# boxplot_df = df[["grade", "price"]]
# data = [boxplot_df[boxplot_df['grade']==grade]['price'] for grade in grades]
box_df = df[['grade', 'price']]
box_df.boxplot(by='grade')

plt.xlabel("grade")
plt.ylabel("price")
# plt.boxplot(data)


#Hint: plt.boxplot
# Out:
# Text(0, 0.5, 'price')

# %% [markdown]
# > Notes:
# > - above chart is similar to one from task 2b
# > - in comparison to 2b, the boxplot gives us more information e.g. median

# %%
#b)
from statsmodels.graphics.mosaicplot import mosaic
#Your code:
mosaic(df, ['bedrooms', 'bathrooms'])
# Out:
# (<Figure size 640x480 with 3 Axes>,
#  {('3', '1.0'): (0.0, 0.0, 0.4288124984177063, 0.16521786481589656),
#   ('3', '2.25'): (0.0,
#    0.1682573784937081,
#    0.4288124984177063,
#    0.1004301852420225),
#   ('3', '3.0'): (0.0,
#    0.27172707741354213,
#    0.4288124984177063,
#    0.018285347959961607),
#   ('3', '2.0'): (0.0,
#    0.2930519390513153,
#    0.4288124984177063,
#    0.09727433838598852),
#   ('3', '4.5'): (0.0,
#    0.3933657911151154,
#    0.4288124984177063,
#    0.00046409512588736274),
#   ('3', '1.5'): (0.0,
#    0.3968693999188143,
#    0.4288124984177063,
#    0.0769469718721226),
#   ('3', '2.5'): (0.0,
#    0.47685588546874846,
#    0.4288124984177063,
#    0.21877444234329674),
#   ('3', '1.75'): (0.0,
#    0.6986698414898568,
#    0.4288124984177063,
#    0.1735715770818688),
#   ('3', '2.75'): (0.0,
#    0.8752809322495371,
#    0.4288124984177063,
#    0.02552523192380424),
#   ('3', '3.25'): (0.0,
#    0.9038456778511529,
#    0.4288124984177063,
# ...

# %% [markdown]
# ## Exercise 4
# "I am interested in the house with 3 bedrooms, 2 bathrooms and 2 floors"
# a) Compute the basic statistics of apartments fulfilling above constraints.
# b) Distinct accepted apartments on any of previously created plots.
# c) Find such apartments with best price to footage ratio.

# %%
#a)
#Your code:
filtered_df = df[(df['bedrooms'] == 3) & (df['bathrooms'] == 2) & (df['floors'] == 2)]
filtered_df.describe()
# Out:
#                  id         price  bedrooms  bathrooms  sqft_living  \
# count  1.540000e+02  1.540000e+02     154.0      154.0   154.000000
# mean   4.397177e+09  5.144986e+05       3.0        2.0  1850.279221
# std    2.849813e+09  2.497661e+05       0.0        0.0   547.585413
# min    7.600057e+06  2.090000e+05       3.0        2.0  1020.000000
# 25%    2.060901e+09  3.769750e+05       3.0        2.0  1452.500000
# 50%    3.630010e+09  4.640000e+05       3.0        2.0  1700.000000
# 75%    7.184074e+09  5.894625e+05       3.0        2.0  2127.500000
# max    9.829200e+09  1.755000e+06       3.0        2.0  3650.000000
#
#             sqft_lot  floors  waterfront        view   condition       grade  \
# count     154.000000   154.0  154.000000  154.000000  154.000000  154.000000
# mean    23678.948052     2.0    0.006494    0.357143    3.435065    7.551948
# std     83324.024708     0.0    0.080582    0.919495    0.713322    0.832684
# ...

# %%
#b)
#Your code:
fig, ax = plt.subplots()
ax.scatter(df["grade"], df["price"], s=5, c='black')
ax.scatter(filtered_df['grade'], filtered_df['price'], c='yellow', edgecolors='black')
plt.show()

# %% [markdown]
# >Notes:
# > - apartments meeting the criteria are located between sixth and tenth grade

# %%
#c)
#Your code:
def calculate_ratio(row):
    return row['price'] / row['sqft_living']
filtered_df = filtered_df.copy()
filtered_df['ratio'] = filtered_df.apply(calculate_ratio, axis=1)
sorted_df = filtered_df.sort_values(by='ratio')
sorted_df.head(5)

#Hint: .loc, .sort_values(), .index
# Out:
#                  id             date     price  bedrooms  bathrooms  \
# 9704   7.452501e+09  20140829T000000  260000.0       3.0        2.0
# 11258  7.937600e+09  20140710T000000  379900.0       3.0        2.0
# 19880  3.832051e+09  20150319T000000  210000.0       3.0        2.0
# 16014  5.104450e+09  20141113T000000  252500.0       3.0        2.0
# 20906  3.355400e+09  20141028T000000  274900.0       3.0        2.0
#
#        sqft_living  sqft_lot  floors  waterfront  view  ...  sqft_above  \
# 9704        2710.0    5000.0     2.0         0.0   0.0  ...      2710.0
# 11258       3110.0   44967.0     2.0         0.0   0.0  ...      3020.0
# 19880       1580.0    4961.0     2.0         0.0   0.0  ...      1580.0
# 16014       1810.0   10684.0     2.0         0.0   0.0  ...      1810.0
# 20906       1936.0    6612.0     2.0         0.0   0.0  ...      1936.0
#
#        sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %% [markdown]
# >Notes:
# > - apartment with best price to footage ratio appers to be with id `9704`
